# %% [markdown]
# ## *Rascunho!!*

# %%
import requests
import pandas as pd
from plyer import notification
from datetime import datetime

# %%
# Notificação
def alerta(nivel, base, etapa, sucesso=False):
    if sucesso:
        titulo = "Sucesso"
        mensagem = f"Extração realizada com sucesso para a base {base} na etapa {etapa}."
    else:
        if nivel == 1:
            titulo = "Alerta Baixo"
        elif nivel == 2:
            titulo = "Alerta Médio"
        elif nivel == 3:
            titulo = "Alerta Alto"
        else:
            titulo = "Alerta Desconhecido"
        
        mensagem = f"Falha no carregamento da base {base} na etapa {etapa};"
    
    data_atual = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

    notification.notify(
        title=f"ATENÇÃO: {titulo}",
        message=f"{mensagem}\n{data_atual}",
        app_name='API_NoobMaster',
        timeout=10
    )

# URLs das APIs
urls = {
    "Europa": "https://restcountries.com/v3.1/region/europe",
    "América": "https://restcountries.com/v3.1/region/america",
    "Africa": "https://restcountries.com/v3.1/region/africa"
}

# Extração dos dados
def extrair_dados(urls):
    tabelas = []  # Para armazenar as tabelas extraídas
    for idioma, url in urls.items():
        try:
            response = requests.get(url)
            response.raise_for_status()
            dados = response.json()
            print(f"Extração bem-sucedida da base {idioma}")
            
            # Notificação de sucesso
            alerta(nivel=1, base=idioma, etapa="EXTRACAO", sucesso=True)
            
            # Transformar os dados em um DataFrame
            df = pd.json_normalize(dados)
            tabelas.append(df)
            
        except requests.exceptions.RequestException as e:
            # Caso ocorra algum erro, gerar alerta
            alerta(nivel=2, base=idioma, etapa="EXTRACAO")
            print(f"Erro na extração da base {idioma}: {e}")

    return tabelas

# %%
tabelas_extraida = extrair_dados(urls)
# Out:
# Extração bem-sucedida da base Europa
# Extração bem-sucedida da base América
# Extração bem-sucedida da base Africa

# %%
europa = tabelas_extraida[0]
america = tabelas_extraida[1]
africa = tabelas_extraida[2]

# %%
europa.columns
# Out:
# Index(['tld', 'cca2', 'ccn3', 'cca3', 'cioc', 'independent', 'status',
#        'unMember', 'capital', 'altSpellings',
#        ...
#        'name.nativeName.spa.common', 'languages.spa', 'languages.eus',
#        'languages.glc', 'name.nativeName.slv.official',
#        'name.nativeName.slv.common', 'languages.slv',
#        'name.nativeName.gle.official', 'name.nativeName.gle.common',
#        'languages.gle'],
#       dtype='object', length=293)

# %%
colunas = list(europa.columns)
print(colunas)
# Out:
# ['tld', 'cca2', 'ccn3', 'cca3', 'cioc', 'independent', 'status', 'unMember', 'capital', 'altSpellings', 'region', 'subregion', 'latlng', 'landlocked', 'borders', 'area', 'flag', 'population', 'fifa', 'timezones', 'continents', 'startOfWeek', 'name.common', 'name.official', 'name.nativeName.nno.official', 'name.nativeName.nno.common', 'name.nativeName.nob.official', 'name.nativeName.nob.common', 'name.nativeName.smi.official', 'name.nativeName.smi.common', 'currencies.NOK.name', 'currencies.NOK.symbol', 'idd.root', 'idd.suffixes', 'languages.nno', 'languages.nob', 'languages.smi', 'translations.ara.official', 'translations.ara.common', 'translations.bre.official', 'translations.bre.common', 'translations.ces.official', 'translations.ces.common', 'translations.cym.official', 'translations.cym.common', 'translations.deu.official', 'translations.deu.common', 'translations.est.official', 'translations.est.common', 'translations.fin.official', 'translations.fin.common', 'translations.fra.official', 'translations.fra.common', 'translations.hrv.official', 'translations.hrv.common', 'translations.hun.official', 'translations.hun.common', 'translations.ita.official', 'translations.ita.common', 'translations.jpn.official', 'translations.jpn.common', 'translations.kor.official', 'translations.kor.common', 'translations.nld.official', 'translations.nld.common', 'translations.per.official', 'translations.per.common', 'translations.pol.official', 'translations.pol.common', 'translations.por.official', 'translations.por.common', 'translations.rus.official', 'translations.rus.common', 'translations.slk.official', 'translations.slk.common', 'translations.spa.official', 'translations.spa.common', 'translations.srp.official', 'translations.srp.common', 'translations.swe.official', 'translations.swe.common', 'translations.tur.official', 'translations.tur.common', 'translations.urd.official', 'translations.urd.common', 'translations.zho.official', 'translations.zho.common', 'demonyms.eng.f', 'demonyms.eng.m', 'demonyms.fra.f', 'demonyms.fra.m', 'maps.googleMaps', 'maps.openStreetMaps', 'gini.2018', 'car.signs', 'car.side', 'flags.png', 'flags.svg', 'flags.alt', 'coatOfArms.png', 'coatOfArms.svg', 'capitalInfo.latlng', 'postalCode.format', 'postalCode.regex', 'name.nativeName.ell.official', 'name.nativeName.ell.common', 'currencies.EUR.name', 'currencies.EUR.symbol', 'languages.ell', 'name.nativeName.swe.official', 'name.nativeName.swe.common', 'languages.swe', 'name.nativeName.fra.official', 'name.nativeName.fra.common', 'name.nativeName.gsw.official', 'name.nativeName.gsw.common', 'name.nativeName.ita.official', 'name.nativeName.ita.common', 'name.nativeName.roh.official', 'name.nativeName.roh.common', 'currencies.CHF.name', 'currencies.CHF.symbol', 'languages.fra', 'languages.gsw', 'languages.ita', 'languages.roh', 'name.nativeName.hrv.official', 'name.nativeName.hrv.common', 'languages.hrv', 'name.nativeName.isl.official', 'name.nativeName.isl.common', 'currencies.ISK.name', 'currencies.ISK.symbol', 'languages.isl', 'gini.2017', 'name.nativeName.deu.official', 'name.nativeName.deu.common', 'name.nativeName.ltz.official', 'name.nativeName.ltz.common', 'languages.deu', 'languages.ltz', 'name.nativeName.hun.official', 'name.nativeName.hun.common', 'currencies.HUF.name', 'currencies.HUF.symbol', 'languages.hun', 'name.nativeName.nld.official', 'name.nativeName.nld.common', 'languages.nld', 'name.nativeName.lit.official', 'name.nativeName.lit.common', 'languages.lit', 'name.nativeName.slk.official', 'name.nativeName.slk.common', 'languages.slk', 'name.nativeName.ron.official', 'name.nativeName.ron.common', 'currencies.MDL.name', 'currencies.MDL.symbol', 'languages.ron', 'name.nativeName.eng.official', 'name.nativeName.eng.common', 'name.nativeName.nrf.official', 'name.nativeName.nrf.common', 'currencies.GBP.name', 'currencies.GBP.symbol', 'currencies.JEP.name', 'currencies.JEP.symbol', 'languages.eng', 'languages.nrf', 'name.nativeName.bel.official', ...

# %%
colunas_importantes = [
    'name.common', 'name.official', 'capital', 'region', 'subregion', 'population', 'area', 'flag', 'timezones', 'continents', 'demonyms.eng.m'
    ]

# %%
df_europa = europa[colunas_importantes]
df_europa
# Out:
#                name.common                                      name.official  \
# 0                   Norway                                  Kingdom of Norway
# 1                   Greece                                  Hellenic Republic
# 2            Åland Islands                                      Åland Islands
# 3              Switzerland                                Swiss Confederation
# 4                  Croatia                                Republic of Croatia
# 5                  Iceland                                            Iceland
# 6               Luxembourg                          Grand Duchy of Luxembourg
# 7                  Hungary                                            Hungary
# 8              Netherlands                         Kingdom of the Netherlands
# 9                Lithuania                              Republic of Lithuania
# 10                Slovakia                                    Slovak Republic
# 11           Liechtenstein                      Principality of Liechtenstein
# 12                 Moldova                                Republic of Moldova
# 13                   Italy                                   Italian Republic
# 14                  Jersey                                Bailiwick of Jersey
# 15                  Monaco                             Principality of Monaco
# 16                 Belarus                                Republic of Belarus
# 17                  Latvia                                 Republic of Latvia
# 18                 Andorra                            Principality of Andorra
# 19                  France                                    French Republic
# 20               Gibraltar                                          Gibraltar
# 21                 Denmark                                 Kingdom of Denmark
# 22         North Macedonia                        Republic of North Macedonia
# 23                   Malta                                  Republic of Malta
# 24                 Czechia                                     Czech Republic
# 25                Guernsey                              Bailiwick of Guernsey
# 26                  Kosovo                                 Republic of Kosovo
# 27  Svalbard and Jan Mayen                              Svalbard og Jan Mayen
# 28              Montenegro                                         Montenegro
# 29           Faroe Islands                                      Faroe Islands
# 30                 Albania                                Republic of Albania
# 31                  Serbia                                 Republic of Serbia
# 32                 Ukraine                                            Ukraine
# 33             Isle of Man                                        Isle of Man
# 34                 Estonia                                Republic of Estonia
# 35                 Romania                                            Romania
# 36                Bulgaria                               Republic of Bulgaria
# 37                 Germany                        Federal Republic of Germany
# 38                  Poland                                 Republic of Poland
# 39          United Kingdom  United Kingdom of Great Britain and Northern I...
# 40                 Finland                                Republic of Finland
# 41                  Sweden                                  Kingdom of Sweden
# 42            Vatican City                                 Vatican City State
# 43                  Russia                                 Russian Federation
# 44                 Austria                                Republic of Austria
# 45                  Cyprus                                 Republic of Cyprus
# 46                Portugal                                Portuguese Republic
# 47  Bosnia and Herzegovina                             Bosnia and Herzegovina
# 48                 Belgium                                 Kingdom of Belgium
# 49                   Spain                                   Kingdom of Spain
# 50                Slovenia                               Republic of Slovenia
# 51              San Marino                             Republic of San Marino
# 52                 Ireland                                Republic of Ireland
#
#                  capital  region         subregion  population         area  \
# 0                 [Oslo]  Europe   Northern Europe     5379475    323802.00
# 1               [Athens]  Europe   Southern Europe    10715549    131990.00
# 2            [Mariehamn]  Europe   Northern Europe       29458      1580.00
# 3                 [Bern]  Europe    Western Europe     8654622     41284.00
# 4               [Zagreb]  Europe  Southeast Europe     4047200     56594.00
# 5            [Reykjavik]  Europe   Northern Europe      366425    103000.00
# 6           [Luxembourg]  Europe    Western Europe      632275      2586.00
# 7             [Budapest]  Europe    Central Europe     9749763     93028.00
# 8            [Amsterdam]  Europe    Western Europe    16655799     41850.00
# 9              [Vilnius]  Europe   Northern Europe     2794700     65300.00
# 10          [Bratislava]  Europe    Central Europe     5458827     49037.00
# 11               [Vaduz]  Europe    Western Europe       38137       160.00
# 12            [Chișinău]  Europe    Eastern Europe     2617820     33846.00
# 13                [Rome]  Europe   Southern Europe    59554023    301336.00
# 14        [Saint Helier]  Europe   Northern Europe      100800       116.00
# 15              [Monaco]  Europe    Western Europe       39244         2.02
# 16               [Minsk]  Europe    Eastern Europe     9398861    207600.00
# 17                [Riga]  Europe   Northern Europe     1901548     64559.00
# 18    [Andorra la Vella]  Europe   Southern Europe       77265       468.00
# 19               [Paris]  Europe    Western Europe    67391582    551695.00
# 20           [Gibraltar]  Europe   Southern Europe       33691         6.00
# 21          [Copenhagen]  Europe   Northern Europe     5831404     43094.00
# 22              [Skopje]  Europe  Southeast Europe     2077132     25713.00
# 23            [Valletta]  Europe   Southern Europe      525285       316.00
# 24              [Prague]  Europe    Central Europe    10698896     78865.00
# 25      [St. Peter Port]  Europe   Northern Europe       62999        78.00
# 26            [Pristina]  Europe  Southeast Europe     1775378     10908.00
# 27        [Longyearbyen]  Europe   Northern Europe        2562     61399.00
# 28           [Podgorica]  Europe  Southeast Europe      621718     13812.00
# 29            [Tórshavn]  Europe   Northern Europe       48865      1393.00
# 30              [Tirana]  Europe  Southeast Europe     2837743     28748.00
# 31            [Belgrade]  Europe  Southeast Europe     6908224     88361.00
# 32                [Kyiv]  Europe    Eastern Europe    44134693    603500.00
# 33             [Douglas]  Europe   Northern Europe       85032       572.00
# 34             [Tallinn]  Europe   Northern Europe     1331057     45227.00
# 35           [Bucharest]  Europe  Southeast Europe    19286123    238391.00
# 36               [Sofia]  Europe  Southeast Europe     6927288    110879.00
# 37              [Berlin]  Europe    Western Europe    83240525    357114.00
# 38              [Warsaw]  Europe    Central Europe    37950802    312679.00
# 39              [London]  Europe   Northern Europe    67215293    242900.00
# 40            [Helsinki]  Europe   Northern Europe     5530719    338424.00
# 41           [Stockholm]  Europe   Northern Europe    10353442    450295.00
# 42        [Vatican City]  Europe   Southern Europe         451         0.44
# 43              [Moscow]  Europe    Eastern Europe   144104080  17098242.00
# 44              [Vienna]  Europe    Central Europe     8917205     83871.00
# 45             [Nicosia]  Europe   Southern Europe     1207361      9251.00
# 46              [Lisbon]  Europe   Southern Europe    10305564     92090.00
# 47            [Sarajevo]  Europe  Southeast Europe     3280815     51209.00
# 48            [Brussels]  Europe    Western Europe    11555997     30528.00
# 49              [Madrid]  Europe   Southern Europe    47351567    505992.00
# 50           [Ljubljana]  Europe    Central Europe     2100126     20273.00
# 51  [City of San Marino]  Europe   Southern Europe       33938        61.00
# 52              [Dublin]  Europe   Northern Europe     4994724     70273.00
#
#    flag                                          timezones      continents  \
# 0    🇳🇴                                        [UTC+01:00]        [Europe]
# 1    🇬🇷                                        [UTC+02:00]        [Europe]
# 2    🇦🇽                                        [UTC+02:00]        [Europe]
# 3    🇨🇭                                        [UTC+01:00]        [Europe]
# 4    🇭🇷                                        [UTC+01:00]        [Europe]
# 5    🇮🇸                                              [UTC]        [Europe]
# 6    🇱🇺                                        [UTC+01:00]        [Europe]
# 7    🇭🇺                                        [UTC+01:00]        [Europe]
# 8    🇳🇱                                        [UTC+01:00]        [Europe]
# 9    🇱🇹                                        [UTC+02:00]        [Europe]
# 10   🇸🇰                                        [UTC+01:00]        [Europe]
# 11   🇱🇮                                        [UTC+01:00]        [Europe]
# 12   🇲🇩                                        [UTC+02:00]        [Europe]
# 13   🇮🇹                                        [UTC+01:00]        [Europe]
# 14   🇯🇪                                        [UTC+01:00]        [Europe]
# 15   🇲🇨                                        [UTC+01:00]        [Europe]
# 16   🇧🇾                                        [UTC+03:00]        [Europe]
# 17   🇱🇻                                        [UTC+02:00]        [Europe]
# 18   🇦🇩                                        [UTC+01:00]        [Europe]
# 19   🇫🇷  [UTC-10:00, UTC-09:30, UTC-09:00, UTC-08:00, U...        [Europe]
# 20   🇬🇮                                        [UTC+01:00]        [Europe]
# 21   🇩🇰  [UTC-04:00, UTC-03:00, UTC-01:00, UTC, UTC+01:00]        [Europe]
# 22   🇲🇰                                        [UTC+01:00]        [Europe]
# 23   🇲🇹                                        [UTC+01:00]        [Europe]
# 24   🇨🇿                                        [UTC+01:00]        [Europe]
# 25   🇬🇬                                        [UTC+00:00]        [Europe]
# 26   🇽🇰                                        [UTC+01:00]        [Europe]
# 27   🇸🇯                                        [UTC+01:00]        [Europe]
# 28   🇲🇪                                        [UTC+01:00]        [Europe]
# 29   🇫🇴                                        [UTC+00:00]        [Europe]
# 30   🇦🇱                                        [UTC+01:00]        [Europe]
# 31   🇷🇸                                        [UTC+01:00]        [Europe]
# 32   🇺🇦                                        [UTC+02:00]        [Europe]
# 33   🇮🇲                                        [UTC+00:00]        [Europe]
# 34   🇪🇪                                        [UTC+02:00]        [Europe]
# 35   🇷🇴                                        [UTC+02:00]        [Europe]
# 36   🇧🇬                                        [UTC+02:00]        [Europe]
# 37   🇩🇪                                        [UTC+01:00]        [Europe]
# 38   🇵🇱                                        [UTC+01:00]        [Europe]
# 39   🇬🇧  [UTC-08:00, UTC-05:00, UTC-04:00, UTC-03:00, U...        [Europe]
# 40   🇫🇮                                        [UTC+02:00]        [Europe]
# 41   🇸🇪                                        [UTC+01:00]        [Europe]
# 42   🇻🇦                                        [UTC+01:00]        [Europe]
# 43   🇷🇺  [UTC+03:00, UTC+04:00, UTC+06:00, UTC+07:00, U...  [Europe, Asia]
# 44   🇦🇹                                        [UTC+01:00]        [Europe]
# 45   🇨🇾                                        [UTC+02:00]        [Europe]
# 46   🇵🇹                                   [UTC-01:00, UTC]        [Europe]
# 47   🇧🇦                                        [UTC+01:00]        [Europe]
# 48   🇧🇪                                        [UTC+01:00]        [Europe]
# 49   🇪🇸                                   [UTC, UTC+01:00]        [Europe]
# 50   🇸🇮                                        [UTC+01:00]        [Europe]
# 51   🇸🇲                                        [UTC+01:00]        [Europe]
# 52   🇮🇪                                              [UTC]        [Europe]
#
#             demonyms.eng.m
# 0                Norwegian
# 1                    Greek
# 2                 Ålandish
# 3                    Swiss
# 4                 Croatian
# 5                Icelander
# 6             Luxembourger
# 7                Hungarian
# 8                    Dutch
# 9               Lithuanian
# 10                  Slovak
# 11         Liechtensteiner
# 12                Moldovan
# 13                 Italian
# 14        Channel Islander
# 15              Monegasque
# 16              Belarusian
# 17                 Latvian
# 18                Andorran
# 19                  French
# 20               Gibraltar
# 21                  Danish
# 22              Macedonian
# 23                 Maltese
# 24                   Czech
# 25        Channel Islander
# 26                 Kosovar
# 27               Norwegian
# 28             Montenegrin
# 29                 Faroese
# 30                Albanian
# 31                 Serbian
# 32               Ukrainian
# 33                    Manx
# 34                Estonian
# 35                Romanian
# 36               Bulgarian
# 37                  German
# 38                  Polish
# 39                 British
# 40                 Finnish
# 41                 Swedish
# 42                 Vatican
# 43                 Russian
# 44                Austrian
# 45                 Cypriot
# 46              Portuguese
# 47  Bosnian, Herzegovinian
# 48                 Belgian
# 49                 Spanish
# 50                 Slovene
# 51             Sammarinese
# 52                   Irish

# %%
df_america = america[colunas_importantes]
df_america.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name.common     56 non-null     object
#  1   name.official   56 non-null     object
#  2   capital         56 non-null     object
#  3   region          56 non-null     object
#  4   subregion       56 non-null     object
#  5   population      56 non-null     int64
#  6   area            56 non-null     float64
#  7   flag            56 non-null     object
#  8   timezones       56 non-null     object
#  9   continents      56 non-null     object
#  10  demonyms.eng.m  56 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 4.9+ KB

# %%
df_africa = africa[colunas_importantes]
df_africa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name.common     59 non-null     object
#  1   name.official   59 non-null     object
#  2   capital         59 non-null     object
#  3   region          59 non-null     object
#  4   subregion       59 non-null     object
#  5   population      59 non-null     int64
#  6   area            59 non-null     float64
#  7   flag            59 non-null     object
#  8   timezones       59 non-null     object
#  9   continents      59 non-null     object
#  10  demonyms.eng.m  59 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 5.2+ KB

# %%
ameria.shape
# Out:
# (56, 214)
